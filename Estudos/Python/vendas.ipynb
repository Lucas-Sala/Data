# %% [markdown]
# #Estudo com Base de dados de Vendas da hashtag

# %%
import pandas as pd

vendas = pd.read_excel("Curso Básico Power BI 2025 - Aula 1 - Introdução ao Power BI/Base Vendas - 2022.xlsx")
produtos = pd.read_excel("Curso Básico Power BI 2025 - Aula 1 - Introdução ao Power BI/Cadastro Produto.xlsx")

# %%
vendas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 371102 entries, 0 to 371101
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Data Venda      371102 non-null  datetime64[us]
#  1   Id Loja         371102 non-null  int64
#  2   Id Produto      371102 non-null  int64
#  3   Id Cliente      371102 non-null  int64
#  4   Qtd. Vendida    371102 non-null  int64
#  5   Qtd. Devolvida  371102 non-null  int64
#  6   Preco Unitario  371102 non-null  str
# dtypes: datetime64[us](1), int64(5), str(1)
# memory usage: 19.8 MB

# %%
vendas.describe()
# Out:
#                        Data Venda        Id Loja     Id Produto  \
# count                      371102  371102.000000  371102.000000
# mean   2022-07-01 12:34:23.251612     690.820413    1589.441997
# min           2022-01-01 00:00:00     423.000000       1.000000
# 25%           2022-04-02 00:00:00     559.000000    1676.000000
# 50%           2022-07-03 00:00:00     693.000000    1706.000000
# 75%           2022-09-28 00:00:00     823.000000    1768.000000
# max           2022-12-31 00:00:00     952.000000    2512.000000
# std                           NaN     152.245359     476.687505
#
#           Id Cliente   Qtd. Vendida  Qtd. Devolvida
# count  371102.000000  371102.000000   371102.000000
# mean     9311.347409       1.000046        0.005629
# min         1.000000       1.000000        0.000000
# 25%      4629.000000       1.000000        0.000000
# 50%      9474.000000       1.000000        0.000000
# 75%     14101.750000       1.000000        0.000000
# ...

# %%
vendas.columns
# Out:
# Index(['Data Venda', 'Id Loja', 'Id Produto', 'Id Cliente', 'Qtd. Vendida',
#        'Qtd. Devolvida', 'Preco Unitario'],
#       dtype='str')

# %%
vendas.shape
# Out:
# (371102, 7)

# %%
vendas.head()
# Out:
#   Data Venda  Id Loja  Id Produto  Id Cliente  Qtd. Vendida  Qtd. Devolvida  \
# 0 2022-01-01      500          83        7604             1               0
# 1 2022-01-01      879          83        7605             2               0
# 2 2022-01-01      679          83        7606             1               0
# 3 2022-01-01      791          83        7607             1               0
# 4 2022-01-01      644          83        7608             4               0
#
#   Preco Unitario
# 0          99.99
# 1          99.99
# 2          99.99
# 3          99.99
# 4          99.99

# %%
#Verificação da existência de campos nulos
vendas.isnull().sum()
# Out:
# Data Venda        0
# Id Loja           0
# Id Produto        0
# Id Cliente        0
# Qtd. Vendida      0
# Qtd. Devolvida    0
# Preco Unitario    0
# dtype: int64

# %%
vendas[vendas.duplicated(keep=False)].sort_values("Id Loja")
# Out:
#        Data Venda  Id Loja  Id Produto  Id Cliente  Qtd. Vendida  \
# 370107 2022-12-31      452         344           1             1
# 370141 2022-12-31      452         344           1             1
# 370216 2022-12-31      465         378           1             1
# 370218 2022-12-31      465         378           1             1
# 370093 2022-12-31      521         414           1             1
# 370181 2022-12-31      521         414           1             1
# 370192 2022-12-31      739         414           1             1
# 370179 2022-12-31      739         414           1             1
# 370131 2022-12-31      860         392           1             1
# 370133 2022-12-31      860         392           1             1
# 370116 2022-12-31      929         347           1             1
# 370123 2022-12-31      929         347           1             1
#
#         Qtd. Devolvida Preco Unitario
# 370107               0         366.00
# 370141               0         366.00
# ...

# %%
vendas[vendas["Preco Unitario"].str.contains(',')]
# Out:
#        Data Venda  Id Loja  Id Produto  Id Cliente  Qtd. Vendida  \
# 4703   2022-01-05      482        1733        5463             1
# 4704   2022-01-05      606        1733        5464             1
# 4705   2022-01-05      809        1733        5465             1
# 4706   2022-01-05      942        1733        5466             1
# 4707   2022-01-05      605        1733        5467             1
# ...           ...      ...         ...         ...           ...
# 368775 2022-12-30      745        1733        8316             1
# 368776 2022-12-30      823        1733        8317             1
# 368777 2022-12-30      638        1733        8318             1
# 368778 2022-12-30      595        1733        8319             1
# 368779 2022-12-30      482        1733        8320             1
#
#         Qtd. Devolvida Preco Unitario
# 4703                 0        2278.,8
# 4704                 0        2278.,8
# 4705                 0        2278.,8
# ...

# %%
vendas["Preco Unitario"].str.contains('.').sum()
# Out:
# np.int64(371102)

# %%
vendas["Preco Unitario"] = (
    vendas["Preco Unitario"]
        .str.replace("R$", "", regex=False)
        .str.replace(",", "", regex=False)
        .str.strip()
)

# %%
vendas["Preco Unitario"] = vendas["Preco Unitario"].astype(float)

# %%
vendas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 371102 entries, 0 to 371101
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Data Venda      371102 non-null  datetime64[us]
#  1   Id Loja         371102 non-null  int64
#  2   Id Produto      371102 non-null  int64
#  3   Id Cliente      371102 non-null  int64
#  4   Qtd. Vendida    371102 non-null  int64
#  5   Qtd. Devolvida  371102 non-null  int64
#  6   Preco Unitario  371102 non-null  float64
# dtypes: datetime64[us](1), float64(1), int64(5)
# memory usage: 19.8 MB

# %%
vendas.describe()
# Out:
#                        Data Venda        Id Loja     Id Produto  \
# count                      371102  371102.000000  371102.000000
# mean   2022-07-01 12:34:23.251612     690.820413    1589.441997
# min           2022-01-01 00:00:00     423.000000       1.000000
# 25%           2022-04-02 00:00:00     559.000000    1676.000000
# 50%           2022-07-03 00:00:00     693.000000    1706.000000
# 75%           2022-09-28 00:00:00     823.000000    1768.000000
# max           2022-12-31 00:00:00     952.000000    2512.000000
# std                           NaN     152.245359     476.687505
#
#           Id Cliente   Qtd. Vendida  Qtd. Devolvida  Preco Unitario
# count  371102.000000  371102.000000   371102.000000   371102.000000
# mean     9311.347409       1.000046        0.005629      180.198455
# min         1.000000       1.000000        0.000000        4.980000
# 25%      4629.000000       1.000000        0.000000        6.990000
# ...

# %%
# Out:
# [423 424 425 426 430 431 432 433 434 435 436 437 438 439 440 441 442 443
#  444 445 446 447 448 449 450 451 452 453 454 455 456 457 458 459 460 461
#  462 463 464 465 466 467 468 469 470 471 472 473 474 475 476 478 479 480
#  481 482 483 485 486 487 488 490 491 492 493 494 495 496 497 498 499 500
#  501 502 503 504 505 506 507 508 509 510 511 512 513 515 516 517 518 519
#  520 521 522 523 524 525 527 528 529 530 531 532 533 534 535 536 537 538
#  539 540 541 542 543 544 545 546 547 548 549 550 551 552 553 554 555 556
#  557 558 559 560 561 562 563 564 565 566 567 568 569 570 571 572 573 574
#  575 576 577 578 579 580 581 582 583 584 585 586 587 588 590 591 592 593
#  594 595 596 597 598 599 600 601 602 603 604 605 606 607 608 609 610 611
#  612 613 614 615 616 617 618 619 620 621 622 623 624 625 626 627 628 629
#  631 632 633 634 635 637 638 639 640 641 642 643 644 645 646 647 648 649
#  650 651 652 653 654 655 656 657 658 659 660 661 662 664 665 666 667 668
# ...
